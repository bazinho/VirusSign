# %%
import os
import os.path
import glob
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold                                                                                                                       
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import svm
from sklearn.model_selection import GridSearchCV
import sklearn_evaluation.plot as skplot
from sklearn.model_selection import learning_curve

import matplotlib.pyplot as plt

import numpy as np
np.random.seed(1)

from keras.preprocessing.image import img_to_array
from keras.utils import np_utils
from keras.preprocessing import image
from keras.applications.inception_resnet_v2 import InceptionResNetV2,preprocess_input

os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
imagedir = "Datasets/ByFamilyPortexPE"

# %%
cur_dir = os.getcwd()
os.chdir(imagedir)  # the parent folder with sub-folders

# Get number of samples per family
list_fams = sorted(os.listdir(os.getcwd()), key=str.lower)  # vector of strings with family names
no_imgs = []  # No. of samples per family
for i in range(len(list_fams)):
    os.chdir(list_fams[i])
    len1 = len(glob.glob('*.png'))  # assuming the images are stored as 'png'
    no_imgs.append(len1)
    os.chdir('..')
num_samples = np.sum(no_imgs)  # total number of all samples

# Compute the labels
y = np.zeros(num_samples)
pos = 0
label = 0
for i in no_imgs:
    print ("Label:%2d\tFamily: %15s\tNumber of images: %d" % (label, list_fams[label], i))
    for j in range(i):
        y[pos] = label
        pos += 1
    label += 1
num_classes = label

# Compute the features
width, height,channels = (224,224,3)
X = np.zeros((num_samples, width, height, channels))
cnt = 0
list_paths = [] # List of image paths
print("Processing images ...")
for i in range(len(list_fams)):
    for img_file in glob.glob(list_fams[i]+'/*.png'):
        #print("[%d] Processing image: %s" % (cnt, img_file))
        list_paths.append(os.path.join(os.getcwd(),img_file))
        img = image.load_img(img_file, target_size=(224, 224))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        X[cnt] = x
        cnt += 1
print("Images processed: %d" %(cnt))

os.chdir(cur_dir)
# Out:
# Label: 0	Family:         allaple	Number of images: 362
# Label: 1	Family:           alman	Number of images: 325
# Label: 2	Family:          autoit	Number of images: 261
# Label: 3	Family:            daws	Number of images: 466
# Label: 4	Family:            delf	Number of images: 359
# Label: 5	Family:         gamarue	Number of images: 259
# Label: 6	Family:          ibryte	Number of images: 347
# Label: 7	Family:          loring	Number of images: 285
# Label: 8	Family:          mydoom	Number of images: 578
# Label: 9	Family:          qukart	Number of images: 253
# Label:10	Family:          ramnit	Number of images: 506
# Label:11	Family:          sality	Number of images: 1401
# Label:12	Family:          simbot	Number of images: 1148
# Label:13	Family:       softpulse	Number of images: 912
# Label:14	Family:          viking	Number of images: 183
# Label:15	Family:         virlock	Number of images: 373
# Label:16	Family:          vobfus	Number of images: 405
# Label:17	Family:          wapomi	Number of images: 345
# Label:18	Family:            zbot	Number of images: 863
# Label:19	Family:          zegost	Number of images: 505
# Processing images ...
# Images processed: 10136

# %%
X.shape
# Out:
# (10136, 224, 224, 3)

# %%
# Creating base_model
image_shape = (224, 224, 3)                                                                                                                                                                                                                                                                                            
base_model = InceptionResNetV2(weights='imagenet', input_shape=image_shape, include_top=False, pooling='avg')

# %%
print("Extracting bottleneck features from convolutional layers ...")
bnfeatures = base_model.predict(X)
# Out:
# Extracting bottleneck features from convolutional layers ...

# %%
bnfeatures.shape
# Out:
# (10136, 1536)

# %%
bnfeatures = np.reshape(bnfeatures,(bnfeatures.shape[0],-1))

# %%
bnfeatures.shape
# Out:
# (10136, 1536)

# %%
# Create stratified k-fold subsets                                                                                                                                        
kfold = 10  # no. of folds                                                                 
skf = StratifiedKFold(kfold, shuffle=True,random_state=1)

# %%
# Training top_model
C_range = np.logspace(-2, 10, 13)
param_grid = dict(C=C_range)

top_model = GridSearchCV(svm.LinearSVC(), param_grid=param_grid, cv=skf, verbose=10, n_jobs=-1)
top_model.fit(bnfeatures,y)  # Training
# Out:
# Fitting 10 folds for each of 13 candidates, totalling 130 fits
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.868627, total= 1.1min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.857283, total= 1.1min
# [CV] C=1.0 ...........................................................
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  1.1min
# [CV] ........................... C=0.01, score=0.872070, total= 1.1min
# [CV] ........................... C=0.01, score=0.891389, total= 1.1min
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.866142, total= 1.1min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.891972, total= 1.1min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.884273, total= 1.1min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.898406, total= 1.4min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.886680, total= 1.4min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.885913, total= 1.4min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.909543, total= 6.2min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.899606, total= 6.3min
# [CV] ............................ C=0.1, score=0.932271, total= 6.3min
# [CV] C=10.0 ..........................................................
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  6.4min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.909990, total= 6.4min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=1.0, score=0.911133, total= 6.6min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=1.0, score=0.920588, total= 6.7min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=1.0, score=0.903543, total= 6.7min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.911706, total= 6.7min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.912402, total= 6.9min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.925636, total= 6.9min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.931507, total= 6.9min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.919722, total= 7.1min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.906863, total= 7.1min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.913086, total= 7.5min
# [CV] C=100.0 .........................................................
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  7.5min
# [CV] ............................ C=1.0, score=0.917323, total= 7.2min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.908012, total= 7.3min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.913690, total= 7.4min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.909543, total= 7.6min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.900591, total= 7.4min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.932271, total= 7.9min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.909804, total= 7.8min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.918731, total= 8.2min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.908203, total= 8.1min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.920744, total= 8.7min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.914370, total=10.4min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.905045, total=10.5min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.912525, total=10.3min
# [CV] C=10000.0 .......................................................
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 16.9min
# [CV] ........................... C=10.0, score=0.909812, total=10.6min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.899606, total=10.2min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.909804, total=10.3min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.925299, total=10.7min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.909722, total=11.0min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.917323, total=10.5min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.918787, total=10.7min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.904297, total=10.8min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.912785, total=10.6min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.898121, total=10.8min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.910714, total=10.9min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.899602, total=10.8min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.904297, total=10.8min
# [CV] C=100000.0 ......................................................
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 19.3min
# [CV] ......................... C=1000.0, score=0.902077, total=10.2min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.919323, total=11.1min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.903922, total=10.7min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.895669, total=10.6min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.915851, total=11.0min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.911794, total=10.5min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.913386, total=11.0min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.907738, total=10.9min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.915507, total=10.7min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.909804, total=10.7min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.896654, total=10.7min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.906250, total=11.0min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.919323, total=11.0min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.919765, total=11.1min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.901088, total=10.8min
# [CV] C=1000000.0 .....................................................
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 28.3min
# [CV] ........................ C=10000.0, score=0.911417, total=10.8min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.920319, total=10.9min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.911794, total=11.2min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.908549, total=11.3min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.907227, total=11.0min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.910714, total=11.4min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.913386, total=10.1min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.896654, total=10.3min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.917808, total=11.2min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.908824, total=10.8min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.920319, total=10.4min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.900099, total=10.9min
# [CV] C=100000000.0 ...................................................
# [CV] ....................... C=100000.0, score=0.909812, total=10.9min
# [CV] C=100000000.0 ...................................................
# [CV] ....................... C=100000.0, score=0.908549, total=11.0min
# [CV] C=100000000.0 ...................................................
# [CV] ....................... C=100000.0, score=0.908730, total=11.0min
# [CV] C=100000000.0 ...................................................
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 30.7min
# [CV] ...................... C=1000000.0, score=0.906250, total=11.0min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.917808, total=10.9min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.908824, total=10.7min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.901088, total=10.6min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.898622, total=11.0min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.909812, total=10.9min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.909449, total=11.0min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.907738, total=10.9min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.920319, total=10.8min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.911531, total=10.9min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.901088, total= 9.9min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.904297, total=10.9min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.919765, total=11.0min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.907843, total=10.9min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.915354, total=11.0min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.897638, total=11.1min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.910803, total=11.0min
# [CV] C=10000000000.0 .................................................
# [Parallel(n_jobs=-1)]: Done  97 out of 130 | elapsed: 40.6min remaining: 13.8min
# [CV] ..................... C=10000000.0, score=0.909722, total=11.0min
# [CV] C=10000000000.0 .................................................
# [CV] ..................... C=10000000.0, score=0.921315, total=10.5min
# [CV] C=10000000000.0 .................................................
# [CV] ..................... C=10000000.0, score=0.908549, total=11.0min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.911765, total=10.7min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.924658, total=10.9min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.907227, total=11.1min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.896654, total=10.9min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.913386, total=10.8min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.903066, total=10.8min
# [CV] C=10000000000.0 .................................................
# [CV] ................... C=1000000000.0, score=0.915354, total= 7.3min
# [CV] .................... C=100000000.0, score=0.910803, total= 8.7min
# [CV] .................... C=100000000.0, score=0.913690, total= 8.3min
# [CV] ................... C=1000000000.0, score=0.902077, total= 7.3min
# [CV] .................. C=10000000000.0, score=0.907843, total= 6.4min
# [Parallel(n_jobs=-1)]: Done 111 out of 130 | elapsed: 47.2min remaining:  8.1min
# [CV] ................... C=1000000000.0, score=0.898622, total= 8.0min
# [CV] .................... C=100000000.0, score=0.908549, total= 8.5min
# [CV] .................. C=10000000000.0, score=0.907227, total= 6.8min
# [CV] .................. C=10000000000.0, score=0.910803, total= 6.1min
# [CV] ................... C=1000000000.0, score=0.913776, total= 7.8min
# [CV] ................... C=1000000000.0, score=0.903320, total= 8.7min
# [CV] .................... C=100000000.0, score=0.920319, total= 8.8min
# [CV] ................... C=1000000000.0, score=0.907843, total= 8.7min
# [CV] ................... C=1000000000.0, score=0.919765, total= 8.7min
# [CV] .................. C=10000000000.0, score=0.913690, total= 6.3min
# [CV] ................... C=1000000000.0, score=0.906746, total= 8.2min
# [CV] ................... C=1000000000.0, score=0.911531, total= 8.1min
# [CV] ................... C=1000000000.0, score=0.916335, total= 8.1min
# [CV] .................. C=10000000000.0, score=0.916830, total= 7.5min
# [Parallel(n_jobs=-1)]: Done 125 out of 130 | elapsed: 48.2min remaining:  1.9min
# [CV] .................. C=10000000000.0, score=0.891732, total= 7.1min
# [CV] .................. C=10000000000.0, score=0.899110, total= 6.9min
# [CV] .................. C=10000000000.0, score=0.914370, total= 7.0min
# [CV] .................. C=10000000000.0, score=0.913519, total= 6.5min
# [CV] .................. C=10000000000.0, score=0.922311, total= 5.9min
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed: 48.7min finished
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=1, shuffle=True),
#        error_score='raise',
#        estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04, 1.e+05,
#        1.e+06, 1.e+07, 1.e+08, 1.e+09, 1.e+10])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=10)

# %%
top_model.cv_results_
# Out:
# {'mean_fit_time': array([ 69.86496792, 404.94089608, 435.07041078, 573.61050332,
#         640.43627887, 644.70460393, 659.57413471, 645.4391428 ,
#         652.78257422, 650.0503644 , 597.30379705, 485.90284452,
#         399.14787369]),
#  'mean_score_time': array([0.04270899, 0.07728381, 0.0560379 , 0.06047397, 0.05123703,
#         0.04225307, 0.05291483, 0.04637408, 0.05119178, 0.0370317 ,
#         0.03838067, 0.01958287, 0.01749837]),
#  'mean_test_score': array([0.88022889, 0.91406867, 0.91663378, 0.91160221, 0.9090371 ,
#         0.90893844, 0.90962904, 0.90913575, 0.90913575, 0.90962904,
#         0.91101026, 0.90953039, 0.9097277 ]),
#  'mean_train_score': array([0.90679038, 0.96885672, 0.99572492, 0.99860799, 0.99826855,
#         0.99810349, 0.99829024, 0.99853134, 0.99849853, 0.99854226,
#         0.99857523, 0.99842178, 0.99836688]),
#  'param_C': masked_array(data=[0.01, 0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0, 100000.0,
#                     1000000.0, 10000000.0, 100000000.0, 1000000000.0,
#                     10000000000.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': ({'C': 0.01},
#   {'C': 0.1},
#   {'C': 1.0},
#   {'C': 10.0},
#   {'C': 100.0},
#   {'C': 1000.0},
#   {'C': 10000.0},
#   {'C': 100000.0},
#   {'C': 1000000.0},
#   {'C': 10000000.0},
#   {'C': 100000000.0},
#   {'C': 1000000000.0},
#   {'C': 10000000000.0}),
#  'rank_test_score': array([13,  2,  1,  3, 11, 12,  6,  9,  9,  6,  4,  8,  5], dtype=int32),
#  'split0_test_score': array([0.87207031, 0.91308594, 0.91113281, 0.90820312, 0.90429688,
#         0.90429688, 0.90625   , 0.90722656, 0.90625   , 0.90429688,
#         0.90722656, 0.90332031, 0.90722656]),
#  'split0_train_score': array([0.90967954, 0.96828358, 0.99626866, 0.99912204, 0.99923178,
#         0.99912204, 0.99912204, 0.99923178, 0.99934153, 0.99934153,
#         0.99901229, 0.99934153, 0.99890255]),
#  'split1_test_score': array([0.89138943, 0.92563601, 0.93150685, 0.92074364, 0.91878669,
#         0.91585127, 0.91976517, 0.91780822, 0.91780822, 0.91976517,
#         0.92465753, 0.91976517, 0.91682975]),
#  'split1_train_score': array([0.90607856, 0.96796138, 0.99572087, 0.99901251, 0.99901251,
#         0.99670836, 0.99813474, 0.99923195, 0.99912223, 0.99901251,
#         0.99912223, 0.99890279, 0.99901251]),
#  'split2_test_score': array([0.86862745, 0.90686275, 0.92058824, 0.90980392, 0.90980392,
#         0.90392157, 0.90980392, 0.90882353, 0.90882353, 0.90784314,
#         0.91176471, 0.90784314, 0.90784314]),
#  'split2_train_score': array([0.90675735, 0.96884599, 0.9961606 , 0.99890303, 0.99934182,
#         0.99725757, 0.99923212, 0.99912242, 0.99912242, 0.99912242,
#         0.99923212, 0.99890303, 0.99934182]),
#  'split3_test_score': array([0.85728346, 0.8996063 , 0.90354331, 0.90059055, 0.8996063 ,
#         0.89566929, 0.89665354, 0.89665354, 0.89862205, 0.8976378 ,
#         0.89665354, 0.89862205, 0.89173228]),
#  'split3_train_score': array([0.90855263, 0.96885965, 0.99528509, 0.99769737, 0.99747807,
#         0.99758772, 0.99747807, 0.99649123, 0.99747807, 0.99638158,
#         0.99802632, 0.99736842, 0.99616228]),
#  'split4_test_score': array([0.86614173, 0.91240157, 0.91732283, 0.91437008, 0.91732283,
#         0.91338583, 0.91141732, 0.91338583, 0.90944882, 0.91535433,
#         0.91338583, 0.91535433, 0.91437008]),
#  'split4_train_score': array([0.90690789, 0.96864035, 0.99583333, 0.99857456, 0.99890351,
#         0.99901316, 0.99901316, 0.99901316, 0.99879386, 0.99912281,
#         0.99890351, 0.99912281, 0.99890351]),
#  'split5_test_score': array([0.884273  , 0.90999011, 0.90801187, 0.90504451, 0.89812067,
#         0.90207715, 0.90108803, 0.90009891, 0.90108803, 0.90108803,
#         0.90306627, 0.90207715, 0.89910979]),
#  'split5_train_score': array([0.90531507, 0.9699726 , 0.99506849, 0.99868493, 0.9990137 ,
#         0.9980274 , 0.99879452, 0.99890411, 0.99857534, 0.99890411,
#         0.99890411, 0.99846575, 0.99868493]),
#  'split6_test_score': array([0.89197225, 0.9197225 , 0.91873142, 0.90981169, 0.91278494,
#         0.91179386, 0.91179386, 0.90981169, 0.90981169, 0.91080278,
#         0.91080278, 0.91377602, 0.91080278]),
#  'split6_train_score': array([0.9044593 , 0.96997918, 0.99583653, 0.99912348, 0.99912348,
#         0.99923304, 0.99923304, 0.99923304, 0.99923304, 0.99912348,
#         0.99934261, 0.99934261, 0.99912348]),
#  'split7_test_score': array([0.8859127 , 0.91170635, 0.91369048, 0.90972222, 0.91071429,
#         0.9077381 , 0.91071429, 0.90873016, 0.9077381 , 0.90972222,
#         0.91369048, 0.90674603, 0.91369048]),
#  'split7_train_score': array([0.90644172, 0.96965381, 0.99583699, 0.99912358, 0.99868536,
#         0.99846626, 0.99704207, 0.99879492, 0.99802805, 0.99868536,
#         0.99769939, 0.99660386, 0.99737073]),
#  'split8_test_score': array([0.88667992, 0.90954274, 0.90954274, 0.91252485, 0.89960239,
#         0.91550696, 0.90854871, 0.90854871, 0.91153082, 0.90854871,
#         0.90854871, 0.91153082, 0.91351889]),
#  'split8_train_score': array([0.90766703, 0.96834611, 0.99550931, 0.99835706, 0.99386637,
#         0.99780942, 0.99715225, 0.99780942, 0.99780942, 0.99791895,
#         0.99759036, 0.99857612, 0.99835706]),
#  'split9_test_score': array([0.89840637, 0.93227092, 0.93227092, 0.9252988 , 0.91932271,
#         0.91932271, 0.92031873, 0.92031873, 0.92031873, 0.92131474,
#         0.92031873, 0.91633466, 0.92231076]),
#  'split9_train_score': array([0.90604468, 0.96802453, 0.9957293 , 0.99748138, 0.99802891,
#         0.9978099 , 0.99770039, 0.99748138, 0.99748138, 0.9978099 ,
#         0.9979194 , 0.99759089, 0.9978099 ]),
#  'std_fit_time': array([ 9.19371329, 24.04990056, 30.66093679, 78.76295314, 15.95056444,
#         15.37163156, 14.82309324, 20.55744543,  7.00601144, 21.7614692 ,
#         67.78971406, 29.53883655, 27.90206088]),
#  'std_score_time': array([0.01209825, 0.0206874 , 0.01368029, 0.03353752, 0.00663987,
#         0.01652494, 0.0161523 , 0.01953475, 0.01198876, 0.01034727,
#         0.01173659, 0.00386192, 0.0120864 ]),
#  'std_test_score': array([0.01268563, 0.00896136, 0.00906004, 0.00681669, 0.00778384,
#         0.00705499, 0.00692871, 0.0067837 , 0.00625946, 0.00723239,
#         0.00759645, 0.0065697 , 0.00840995]),
#  'std_train_score': array([0.00145021, 0.000726  , 0.00034541, 0.00056701, 0.00156709,
#         0.00079868, 0.00084436, 0.00089719, 0.00069955, 0.00087271,
#         0.00064769, 0.00088198, 0.00093695])}

# %%
top_model.grid_scores_
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.88023, std: 0.01269, params: {'C': 0.01},
#  mean: 0.91407, std: 0.00897, params: {'C': 0.1},
#  mean: 0.91663, std: 0.00906, params: {'C': 1.0},
#  mean: 0.91160, std: 0.00682, params: {'C': 10.0},
#  mean: 0.90904, std: 0.00779, params: {'C': 100.0},
#  mean: 0.90894, std: 0.00706, params: {'C': 1000.0},
#  mean: 0.90963, std: 0.00693, params: {'C': 10000.0},
#  mean: 0.90914, std: 0.00679, params: {'C': 100000.0},
#  mean: 0.90914, std: 0.00626, params: {'C': 1000000.0},
#  mean: 0.90963, std: 0.00723, params: {'C': 10000000.0},
#  mean: 0.91101, std: 0.00759, params: {'C': 100000000.0},
#  mean: 0.90953, std: 0.00656, params: {'C': 1000000000.0},
#  mean: 0.90973, std: 0.00841, params: {'C': 10000000000.0}]

# %%
print("Best parameters: %s - score: %0.4f" % (top_model.best_params_, top_model.best_score_))
# Out:
# Best parameters: {'C': 1.0} - score: 0.9166
