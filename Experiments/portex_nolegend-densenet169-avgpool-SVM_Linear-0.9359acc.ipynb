# %%
import os
import os.path
import glob
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold                                                                                                                       
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import svm
from sklearn.model_selection import GridSearchCV
import sklearn_evaluation.plot as skplot
from sklearn.model_selection import learning_curve

import matplotlib.pyplot as plt

import numpy as np
np.random.seed(1)

from keras.preprocessing.image import img_to_array
from keras.utils import np_utils
from keras.preprocessing import image
from keras.applications.densenet import DenseNet169,preprocess_input

os.environ['CUDA_VISIBLE_DEVICES'] = '0'
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
imagedir = "Datasets/ByFamilyPortexNoLegend"

# %%
cur_dir = os.getcwd()
os.chdir(imagedir)  # the parent folder with sub-folders

# Get number of samples per family
list_fams = sorted(os.listdir(os.getcwd()), key=str.lower)  # vector of strings with family names
no_imgs = []  # No. of samples per family
for i in range(len(list_fams)):
    os.chdir(list_fams[i])
    len1 = len(glob.glob('*.png'))  # assuming the images are stored as 'png'
    no_imgs.append(len1)
    os.chdir('..')
num_samples = np.sum(no_imgs)  # total number of all samples

# Compute the labels
y = np.zeros(num_samples)
pos = 0
label = 0
for i in no_imgs:
    print ("Label:%2d\tFamily: %15s\tNumber of images: %d" % (label, list_fams[label], i))
    for j in range(i):
        y[pos] = label
        pos += 1
    label += 1
num_classes = label

# Compute the features
width, height,channels = (224,224,3)
X = np.zeros((num_samples, width, height, channels))
cnt = 0
list_paths = [] # List of image paths
print("Processing images ...")
for i in range(len(list_fams)):
    for img_file in glob.glob(list_fams[i]+'/*.png'):
        #print("[%d] Processing image: %s" % (cnt, img_file))
        list_paths.append(os.path.join(os.getcwd(),img_file))
        img = image.load_img(img_file, target_size=(224, 224))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        X[cnt] = x
        cnt += 1
print("Images processed: %d" %(cnt))

os.chdir(cur_dir)
# Out:
# Label: 0	Family:         allaple	Number of images: 362
# Label: 1	Family:           alman	Number of images: 325
# Label: 2	Family:          autoit	Number of images: 261
# Label: 3	Family:            daws	Number of images: 466
# Label: 4	Family:            delf	Number of images: 359
# Label: 5	Family:         gamarue	Number of images: 259
# Label: 6	Family:          ibryte	Number of images: 347
# Label: 7	Family:          loring	Number of images: 285
# Label: 8	Family:          mydoom	Number of images: 578
# Label: 9	Family:          qukart	Number of images: 253
# Label:10	Family:          ramnit	Number of images: 506
# Label:11	Family:          sality	Number of images: 1401
# Label:12	Family:          simbot	Number of images: 1148
# Label:13	Family:       softpulse	Number of images: 912
# Label:14	Family:          viking	Number of images: 183
# Label:15	Family:         virlock	Number of images: 373
# Label:16	Family:          vobfus	Number of images: 405
# Label:17	Family:          wapomi	Number of images: 345
# Label:18	Family:            zbot	Number of images: 863
# Label:19	Family:          zegost	Number of images: 505
# Processing images ...
# Images processed: 10136

# %%
X.shape
# Out:
# (10136, 224, 224, 3)

# %%
# Creating base_model
image_shape = (224, 224, 3)                                                                                                                                                                                                                                                                                            
base_model = DenseNet169(weights='imagenet', input_shape=image_shape, include_top=False, pooling='avg')

# %%
print("Extracting bottleneck features from convolutional layers ...")
bnfeatures = base_model.predict(X)
# Out:
# Extracting bottleneck features from convolutional layers ...

# %%
bnfeatures.shape
# Out:
# (10136, 1, 1, 1664)

# %%
bnfeatures = np.reshape(bnfeatures,(bnfeatures.shape[0],-1))

# %%
bnfeatures.shape
# Out:
# (10136, 1664)

# %%
# Create stratified k-fold subsets                                                                                                                                        
kfold = 10  # no. of folds                                                                 
skf = StratifiedKFold(kfold, shuffle=True,random_state=1)

# %%
# Training top_model
C_range = np.logspace(-2, 10, 13)
param_grid = dict(C=C_range)

top_model = GridSearchCV(svm.LinearSVC(), param_grid=param_grid, cv=skf, verbose=10, n_jobs=-1)
top_model.fit(bnfeatures,y)  # Training
# Out:
# Fitting 10 folds for each of 13 candidates, totalling 130 fits
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.930664, total= 1.0min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.933464, total= 1.1min
# [CV] C=1.0 ...........................................................
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  1.1min
# [CV] ........................... C=0.01, score=0.930417, total= 1.1min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.926181, total= 1.1min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.937500, total= 1.2min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.938675, total= 1.2min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.943508, total= 1.2min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.933333, total= 1.3min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.925299, total= 1.3min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.939961, total= 1.3min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=1.0, score=0.927451, total= 2.7min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=1.0, score=0.927593, total= 2.7min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=1.0, score=0.931641, total= 2.8min
# [CV] C=10.0 ..........................................................
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  2.8min
# [CV] ............................ C=0.1, score=0.937500, total= 2.8min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.931102, total= 2.8min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.934314, total= 2.9min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.943620, total= 2.9min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.928429, total= 2.9min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.941526, total= 2.9min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.936508, total= 2.9min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.926295, total= 2.9min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.942913, total= 2.9min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.920276, total= 3.0min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.936399, total= 3.1min
# [CV] C=100.0 .........................................................
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  3.1min
# [CV] ........................... C=10.0, score=0.927734, total= 2.6min
# [CV] C=100.0 .........................................................
# [CV] ........................... C=10.0, score=0.926471, total= 2.6min
# [CV] C=100.0 .........................................................
# [CV] ........................... C=10.0, score=0.924658, total= 2.6min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.921471, total= 2.7min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.934718, total= 2.8min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.924303, total= 2.7min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.918307, total= 2.6min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.928150, total= 2.9min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.934589, total= 2.9min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.927579, total= 2.9min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.925595, total= 2.7min
# [CV] C=1000.0 ........................................................
# [CV] .......................... C=100.0, score=0.925781, total= 2.6min
# [CV] C=1000.0 ........................................................
# [CV] .......................... C=100.0, score=0.923679, total= 2.6min
# [CV] C=10000.0 .......................................................
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  5.6min
# [CV] ........................... C=10.0, score=0.911531, total= 2.7min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.918327, total= 2.7min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.917323, total= 2.6min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.928783, total= 2.9min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.929633, total= 2.9min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.921260, total= 2.9min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.921569, total= 2.8min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.935707, total= 2.8min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.924213, total= 3.0min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.934589, total= 2.9min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.922619, total= 2.9min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.925781, total= 2.6min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.920319, total= 2.7min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.910537, total= 2.7min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  6.5min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.923679, total= 2.7min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.916339, total= 2.7min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.927165, total= 2.7min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.924510, total= 2.8min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.917903, total= 2.8min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.931615, total= 2.9min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.923611, total= 2.9min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.925781, total= 2.6min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.922701, total= 2.6min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.926471, total= 2.6min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.912525, total= 2.7min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.919323, total= 2.7min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.917323, total= 2.6min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.932740, total= 2.9min
# [CV] C=1000000.0 .....................................................
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  8.6min
# [CV] ........................ C=10000.0, score=0.927651, total= 2.9min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.924213, total= 2.9min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.921627, total= 2.9min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.920477, total= 2.9min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.920319, total= 2.9min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.925781, total= 2.8min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.920744, total= 2.8min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.921569, total= 2.6min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.916339, total= 2.6min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.922849, total= 2.6min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.927651, total= 2.7min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.924213, total= 2.7min
# [CV] C=100000000.0 ...................................................
# [CV] ....................... C=100000.0, score=0.919643, total= 2.7min
# [CV] C=100000000.0 ...................................................
# [CV] ....................... C=100000.0, score=0.918489, total= 2.9min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.928711, total= 2.8min
# [CV] C=100000000.0 ...................................................
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:  9.7min
# [CV] ....................... C=100000.0, score=0.917331, total= 2.9min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.923679, total= 2.9min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.921569, total= 2.6min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.916339, total= 2.6min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.922849, total= 2.6min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.924213, total= 2.7min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.927651, total= 2.7min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.920635, total= 2.7min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.915507, total= 2.9min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.928711, total= 2.8min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.925490, total= 2.8min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.922701, total= 2.9min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.917331, total= 2.9min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.916339, total= 2.8min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.922849, total= 2.8min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.930624, total= 2.6min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.924213, total= 3.0min
# [CV] C=10000000000.0 .................................................
# [Parallel(n_jobs=-1)]: Done  97 out of 130 | elapsed: 11.8min remaining:  4.0min
# [CV] ..................... C=10000000.0, score=0.918651, total= 2.7min
# [CV] C=10000000000.0 .................................................
# [CV] ..................... C=10000000.0, score=0.910537, total= 2.7min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.923828, total= 2.6min
# [CV] C=10000000000.0 .................................................
# [CV] ..................... C=10000000.0, score=0.920319, total= 2.7min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.923679, total= 2.6min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.926471, total= 2.8min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.918307, total= 2.8min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.932740, total= 2.9min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.922244, total= 2.9min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.929633, total= 2.6min
# [CV] .................... C=100000000.0, score=0.918651, total= 2.7min
# [CV] ................... C=1000000000.0, score=0.925781, total= 2.6min
# [CV] .................... C=100000000.0, score=0.914513, total= 2.7min
# [CV] ................... C=1000000000.0, score=0.922701, total= 2.6min
# [Parallel(n_jobs=-1)]: Done 111 out of 130 | elapsed: 13.6min remaining:  2.3min
# [CV] .................... C=100000000.0, score=0.920319, total= 2.6min
# [CV] ................... C=1000000000.0, score=0.926471, total= 2.6min
# [CV] ................... C=1000000000.0, score=0.919323, total= 2.4min
# [CV] ................... C=1000000000.0, score=0.918307, total= 2.7min
# [CV] .................. C=10000000000.0, score=0.924658, total= 2.3min
# [CV] .................. C=10000000000.0, score=0.921260, total= 2.3min
# [CV] .................. C=10000000000.0, score=0.923529, total= 2.4min
# [CV] ................... C=1000000000.0, score=0.930624, total= 2.7min
# [CV] .................. C=10000000000.0, score=0.926805, total= 2.2min
# [CV] .................. C=10000000000.0, score=0.923228, total= 2.3min
# [CV] ................... C=1000000000.0, score=0.910433, total= 2.8min
# [CV] ................... C=1000000000.0, score=0.932740, total= 2.8min
# [CV] ................... C=1000000000.0, score=0.907555, total= 2.7min
# [CV] .................. C=10000000000.0, score=0.925781, total= 2.6min
# [Parallel(n_jobs=-1)]: Done 125 out of 130 | elapsed: 14.4min remaining:   34.6s
# [CV] ................... C=1000000000.0, score=0.922619, total= 2.7min
# [CV] .................. C=10000000000.0, score=0.925669, total= 2.2min
# [CV] .................. C=10000000000.0, score=0.921627, total= 2.2min
# [CV] .................. C=10000000000.0, score=0.910537, total= 2.1min
# [CV] .................. C=10000000000.0, score=0.919323, total= 2.1min
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed: 14.8min finished
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=1, shuffle=True),
#        error_score='raise',
#        estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04, 1.e+05,
#        1.e+06, 1.e+07, 1.e+08, 1.e+09, 1.e+10])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=10)

# %%
top_model.cv_results_
# Out:
# {'mean_fit_time': array([ 71.49343133, 174.95260565, 168.53528562, 162.50930343,
#         165.76402185, 164.12141414, 166.3302485 , 164.2829174 ,
#         164.80210857, 166.69955406, 163.85321062, 159.33059723,
#         136.00640645]),
#  'mean_score_time': array([0.03899148, 0.04094031, 0.03132496, 0.03067315, 0.03138914,
#         0.02616804, 0.02679329, 0.02874308, 0.02771466, 0.02723219,
#         0.02553303, 0.01738019, 0.0133203 ]),
#  'mean_test_score': array([0.93389897, 0.93587214, 0.92778216, 0.92324388, 0.92363852,
#         0.9222573 , 0.92393449, 0.92146803, 0.92186267, 0.92205998,
#         0.92304657, 0.92166535, 0.9222573 ]),
#  'mean_train_score': array([0.97836076, 0.99684286, 0.999726  , 0.99975886, 0.99966022,
#         0.99957255, 0.99973689, 0.99967119, 0.99952878, 0.9996493 ,
#         0.99970405, 0.99948474, 0.99966021]),
#  'param_C': masked_array(data=[0.01, 0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0, 100000.0,
#                     1000000.0, 10000000.0, 100000000.0, 1000000000.0,
#                     10000000000.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': ({'C': 0.01},
#   {'C': 0.1},
#   {'C': 1.0},
#   {'C': 10.0},
#   {'C': 100.0},
#   {'C': 1000.0},
#   {'C': 10000.0},
#   {'C': 100000.0},
#   {'C': 1000000.0},
#   {'C': 10000000.0},
#   {'C': 100000000.0},
#   {'C': 1000000000.0},
#   {'C': 10000000000.0}),
#  'rank_test_score': array([ 2,  1,  3,  6,  5,  8,  4, 13, 11, 10,  7, 12,  8], dtype=int32),
#  'split0_test_score': array([0.93066406, 0.9375    , 0.93164062, 0.92773438, 0.92578125,
#         0.92578125, 0.92578125, 0.92578125, 0.92871094, 0.92871094,
#         0.92382812, 0.92578125, 0.92578125]),
#  'split0_train_score': array([0.97805092, 0.99670764, 0.99989025, 0.99978051, 0.99978051,
#         0.99989025, 0.99956102, 0.99978051, 0.99978051, 0.99978051,
#         0.99978051, 0.99967076, 0.99967076]),
#  'split1_test_score': array([0.9334638 , 0.93639922, 0.92759295, 0.92465753, 0.92367906,
#         0.92367906, 0.92270059, 0.92074364, 0.92367906, 0.92270059,
#         0.92367906, 0.92270059, 0.92465753]),
#  'split1_train_score': array([0.97794602, 0.9969278 , 0.99978056, 0.99978056, 0.99967084,
#         0.99978056, 0.99967084, 0.99978056, 0.99978056, 0.99978056,
#         0.99967084, 0.99978056, 0.99978056]),
#  'split2_test_score': array([0.93333333, 0.93431373, 0.92745098, 0.92647059, 0.92156863,
#         0.9245098 , 0.92647059, 0.92156863, 0.92156863, 0.9254902 ,
#         0.92647059, 0.92647059, 0.92352941]),
#  'split2_train_score': array([0.97838964, 0.99670908, 0.99978061, 0.99978061, 0.99956121,
#         0.99967091, 0.99978061, 0.99967091, 0.99967091, 0.99978061,
#         0.99978061, 0.99978061, 0.99978061]),
#  'split3_test_score': array([0.9261811 , 0.93110236, 0.92027559, 0.91830709, 0.91732283,
#         0.91633858, 0.91732283, 0.91633858, 0.91633858, 0.91633858,
#         0.91830709, 0.91830709, 0.92125984]),
#  'split3_train_score': array([0.97817982, 0.99671053, 0.9997807 , 0.9997807 , 0.99967105,
#         0.9997807 , 0.9997807 , 0.9997807 , 0.9997807 , 0.9997807 ,
#         0.9997807 , 0.9997807 , 0.9995614 ]),
#  'split4_test_score': array([0.93996063, 0.94291339, 0.92814961, 0.92125984, 0.9242126 ,
#         0.92716535, 0.9242126 , 0.9242126 , 0.9242126 , 0.9242126 ,
#         0.92224409, 0.91043307, 0.92322835]),
#  'split4_train_score': array([0.97730263, 0.99692982, 0.9995614 , 0.9997807 , 0.9997807 ,
#         0.9997807 , 0.9997807 , 0.9997807 , 0.9997807 , 0.9997807 ,
#         0.99967105, 0.99736842, 0.9997807 ]),
#  'split5_test_score': array([0.93867458, 0.94362018, 0.9347181 , 0.92878338, 0.93570722,
#         0.91790307, 0.93273986, 0.92284866, 0.92284866, 0.92284866,
#         0.93273986, 0.93273986, 0.92680514]),
#  'split5_train_score': array([0.97961644, 0.99649315, 0.99978082, 0.99978082, 0.99978082,
#         0.99769863, 0.99978082, 0.99967123, 0.99967123, 0.99967123,
#         0.99956164, 0.99967123, 0.99978082]),
#  'split6_test_score': array([0.94350842, 0.94152626, 0.9345887 , 0.9296333 , 0.9345887 ,
#         0.93161546, 0.92765114, 0.92765114, 0.92765114, 0.93062438,
#         0.9296333 , 0.93062438, 0.92566898]),
#  'split6_train_score': array([0.97819656, 0.99649392, 0.99978087, 0.99989043, 0.99989043,
#         0.99989043, 0.99978087, 0.99978087, 0.99978087, 0.99901391,
#         0.99989043, 0.99978087, 0.99912348]),
#  'split7_test_score': array([0.9375    , 0.93650794, 0.92757937, 0.92559524, 0.92261905,
#         0.92361111, 0.92162698, 0.91964286, 0.92063492, 0.91865079,
#         0.91865079, 0.92261905, 0.92162698]),
#  'split7_train_score': array([0.9780894 , 0.99693252, 0.99967134, 0.99967134, 0.99967134,
#         0.99978089, 0.99978089, 0.99901402, 0.99769939, 0.99967134,
#         0.99967134, 0.99978089, 0.99978089]),
#  'split8_test_score': array([0.9304175 , 0.92842942, 0.92147117, 0.91153082, 0.91053678,
#         0.91252485, 0.92047714, 0.91848907, 0.91550696, 0.91053678,
#         0.91451292, 0.90755467, 0.91053678]),
#  'split8_train_score': array([0.97973713, 0.99704272, 0.99978094, 0.99967141, 0.9992333 ,
#         0.99978094, 0.99967141, 0.99978094, 0.99967141, 0.99978094,
#         0.99978094, 0.99956188, 0.99967141]),
#  'split9_test_score': array([0.9252988 , 0.92629482, 0.92430279, 0.91832669, 0.92031873,
#         0.91932271, 0.92031873, 0.91733068, 0.91733068, 0.92031873,
#         0.92031873, 0.91932271, 0.91932271]),
#  'split9_train_score': array([0.97809899, 0.99748138, 0.99945247, 0.99967148, 0.99956198,
#         0.99967148, 0.99978099, 0.99967148, 0.99967148, 0.99945247,
#         0.99945247, 0.99967148, 0.99967148]),
#  'std_fit_time': array([5.32453247, 4.39802642, 6.87573025, 7.7138602 , 7.58108517,
#         5.75693968, 8.32805746, 6.51617585, 6.94031092, 5.82954852,
#         6.31295486, 6.5006243 , 8.43108286]),
#  'std_score_time': array([0.0050689 , 0.00650351, 0.00675803, 0.00779537, 0.00984537,
#         0.00250025, 0.0033439 , 0.00889317, 0.00504438, 0.00321945,
#         0.0036568 , 0.00281734, 0.00199749]),
#  'std_test_score': array([0.0056611 , 0.00561998, 0.00466336, 0.00545986, 0.00704433,
#         0.00537961, 0.00420171, 0.00349704, 0.00427991, 0.00560702,
#         0.00521297, 0.00765106, 0.00446551]),
#  'std_train_score': array([7.11439755e-04, 2.77168121e-04, 1.22417543e-04, 6.56519199e-05,
#         1.72800499e-04, 6.28472830e-04, 7.28536630e-05, 2.24464175e-04,
#         6.11973905e-04, 2.33873761e-04, 1.20443118e-04, 7.09017135e-04,
#         1.92565508e-04])}

# %%
top_model.grid_scores_
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.93390, std: 0.00567, params: {'C': 0.01},
#  mean: 0.93587, std: 0.00563, params: {'C': 0.1},
#  mean: 0.92778, std: 0.00467, params: {'C': 1.0},
#  mean: 0.92324, std: 0.00547, params: {'C': 10.0},
#  mean: 0.92364, std: 0.00706, params: {'C': 100.0},
#  mean: 0.92226, std: 0.00539, params: {'C': 1000.0},
#  mean: 0.92393, std: 0.00421, params: {'C': 10000.0},
#  mean: 0.92147, std: 0.00350, params: {'C': 100000.0},
#  mean: 0.92186, std: 0.00428, params: {'C': 1000000.0},
#  mean: 0.92206, std: 0.00561, params: {'C': 10000000.0},
#  mean: 0.92305, std: 0.00522, params: {'C': 100000000.0},
#  mean: 0.92167, std: 0.00766, params: {'C': 1000000000.0},
#  mean: 0.92226, std: 0.00448, params: {'C': 10000000000.0}]

# %%
print("Best parameters: %s - score: %0.4f" % (top_model.best_params_, top_model.best_score_))
# Out:
# Best parameters: {'C': 0.1} - score: 0.9359
