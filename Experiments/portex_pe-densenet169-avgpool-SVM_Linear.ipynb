# %%
import os
import os.path
import glob
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold                                                                                                                       
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import svm
from sklearn.model_selection import GridSearchCV
import sklearn_evaluation.plot as skplot
from sklearn.model_selection import learning_curve

import matplotlib.pyplot as plt

import numpy as np
np.random.seed(1)

from keras.preprocessing.image import img_to_array
from keras.utils import np_utils
from keras.preprocessing import image
from keras.applications.densenet import DenseNet169,preprocess_input

os.environ['CUDA_VISIBLE_DEVICES'] = '1'
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
imagedir = "Datasets/ByFamilyPortexPE"

# %%
cur_dir = os.getcwd()
os.chdir(imagedir)  # the parent folder with sub-folders

# Get number of samples per family
list_fams = sorted(os.listdir(os.getcwd()), key=str.lower)  # vector of strings with family names
no_imgs = []  # No. of samples per family
for i in range(len(list_fams)):
    os.chdir(list_fams[i])
    len1 = len(glob.glob('*.png'))  # assuming the images are stored as 'png'
    no_imgs.append(len1)
    os.chdir('..')
num_samples = np.sum(no_imgs)  # total number of all samples

# Compute the labels
y = np.zeros(num_samples)
pos = 0
label = 0
for i in no_imgs:
    print ("Label:%2d\tFamily: %15s\tNumber of images: %d" % (label, list_fams[label], i))
    for j in range(i):
        y[pos] = label
        pos += 1
    label += 1
num_classes = label

# Compute the features
width, height,channels = (224,224,3)
X = np.zeros((num_samples, width, height, channels))
cnt = 0
list_paths = [] # List of image paths
print("Processing images ...")
for i in range(len(list_fams)):
    for img_file in glob.glob(list_fams[i]+'/*.png'):
        #print("[%d] Processing image: %s" % (cnt, img_file))
        list_paths.append(os.path.join(os.getcwd(),img_file))
        img = image.load_img(img_file, target_size=(224, 224))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        X[cnt] = x
        cnt += 1
print("Images processed: %d" %(cnt))

os.chdir(cur_dir)
# Out:
# Label: 0	Family:         allaple	Number of images: 362
# Label: 1	Family:           alman	Number of images: 325
# Label: 2	Family:          autoit	Number of images: 261
# Label: 3	Family:            daws	Number of images: 466
# Label: 4	Family:            delf	Number of images: 359
# Label: 5	Family:         gamarue	Number of images: 259
# Label: 6	Family:          ibryte	Number of images: 347
# Label: 7	Family:          loring	Number of images: 285
# Label: 8	Family:          mydoom	Number of images: 578
# Label: 9	Family:          qukart	Number of images: 253
# Label:10	Family:          ramnit	Number of images: 506
# Label:11	Family:          sality	Number of images: 1401
# Label:12	Family:          simbot	Number of images: 1148
# Label:13	Family:       softpulse	Number of images: 912
# Label:14	Family:          viking	Number of images: 183
# Label:15	Family:         virlock	Number of images: 373
# Label:16	Family:          vobfus	Number of images: 405
# Label:17	Family:          wapomi	Number of images: 345
# Label:18	Family:            zbot	Number of images: 863
# Label:19	Family:          zegost	Number of images: 505
# Processing images ...
# Images processed: 10136

# %%
X.shape
# Out:
# (10136, 224, 224, 3)

# %%
# Creating base_model
image_shape = (224, 224, 3)                                                                                                                                                                                                                                                                                            
base_model = DenseNet169(weights='imagenet', input_shape=image_shape, include_top=False, pooling='avg')

# %%
print("Extracting bottleneck features from convolutional layers ...")
bnfeatures = base_model.predict(X)
# Out:
# Extracting bottleneck features from convolutional layers ...

# %%
bnfeatures.shape
# Out:
# (10136, 1, 1, 1664)

# %%
bnfeatures = np.reshape(bnfeatures,(bnfeatures.shape[0],-1))

# %%
bnfeatures.shape
# Out:
# (10136, 1664)

# %%
# Create stratified k-fold subsets                                                                                                                                        
kfold = 10  # no. of folds                                                                 
skf = StratifiedKFold(kfold, shuffle=True,random_state=1)

# %%
# Training top_model
C_range = np.logspace(-2, 10, 13)
param_grid = dict(C=C_range)

top_model = GridSearchCV(svm.LinearSVC(), param_grid=param_grid, cv=skf, verbose=10, n_jobs=-1)
top_model.fit(bnfeatures,y)  # Training
# Out:
# Fitting 10 folds for each of 13 candidates, totalling 130 fits
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.926758, total= 2.3min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.923611, total= 2.3min
# [CV] C=1.0 ...........................................................
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  2.4min
# [CV] ........................... C=0.01, score=0.927165, total= 2.4min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.919608, total= 2.4min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.919881, total= 2.5min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.935259, total= 2.6min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.922465, total= 2.8min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.932607, total= 3.0min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.930528, total= 3.2min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.914370, total= 3.3min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.927794, total= 8.0min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.918627, total= 8.0min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.929688, total= 8.2min
# [CV] C=10.0 ..........................................................
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  8.3min
# [CV] ............................ C=0.1, score=0.937008, total= 8.3min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=1.0, score=0.915686, total= 9.1min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=1.0, score=0.912402, total= 9.3min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=1.0, score=0.922619, total= 7.1min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.917323, total= 9.6min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.915507, total= 7.3min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.939335, total= 9.8min
# [CV] ............................ C=0.1, score=0.922619, total= 9.7min
# [CV] C=100.0 .........................................................
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.935580, total= 9.8min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.920477, total= 9.7min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.930118, total= 7.6min
# [CV] C=100.0 .........................................................
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  9.9min
# [CV] ............................ C=1.0, score=0.922696, total= 7.5min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.927593, total= 9.8min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.923828, total= 9.9min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.920870, total= 7.7min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=0.1, score=0.934263, total=10.1min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.925299, total= 7.7min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.912745, total= 9.0min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.922701, total= 9.2min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.917323, total= 9.0min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.922852, total= 9.6min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.919643, total= 7.0min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.924678, total= 7.3min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.921260, total= 7.5min
# [CV] C=10000.0 .......................................................
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 15.6min
# [CV] ........................... C=10.0, score=0.915925, total= 7.7min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.915675, total= 6.6min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.908824, total= 7.0min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.914513, total= 7.0min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.919922, total= 7.4min
# [CV] C=10000.0 .......................................................
# [CV] ......................... C=1000.0, score=0.922701, total= 6.9min
# [CV] C=10000.0 .......................................................
# [CV] ......................... C=1000.0, score=0.910433, total= 7.0min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.913519, total= 8.9min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.913386, total= 8.5min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.922701, total= 8.6min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.920714, total= 8.5min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.923228, total= 8.6min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.918892, total= 8.7min
# [CV] C=100000.0 ......................................................
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 18.6min
# [CV] ......................... C=1000.0, score=0.910784, total= 8.4min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.924805, total= 8.9min
# [CV] C=100000.0 ......................................................
# [CV] ........................... C=10.0, score=0.920319, total= 9.4min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.919323, total= 9.0min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.915675, total= 7.8min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.917903, total= 8.6min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.922244, total= 8.8min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.920714, total= 9.0min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.913519, total= 7.2min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.917808, total= 7.1min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.920319, total= 7.4min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.918945, total= 7.4min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.912745, total= 7.0min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.910433, total= 7.0min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.916667, total= 6.5min
# [CV] C=1000000.0 .....................................................
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 23.9min
# [CV] ........................ C=10000.0, score=0.925197, total= 7.2min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.916914, total= 7.2min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.924678, total= 7.3min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.912525, total= 8.3min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.921260, total= 8.0min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.918327, total= 8.3min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.917323, total= 8.1min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.921627, total= 7.7min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.912745, total= 8.2min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.914936, total= 7.9min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.924658, total= 8.4min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.923828, total= 8.5min
# [CV] C=100000000.0 ...................................................
# [CV] ....................... C=100000.0, score=0.921705, total= 8.0min
# [CV] C=100000000.0 ...................................................
# [CV] ....................... C=100000.0, score=0.909543, total= 7.8min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.912745, total= 5.8min
# [CV] C=100000000.0 ...................................................
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 28.4min
# [CV] ...................... C=1000000.0, score=0.917659, total= 4.6min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.914936, total= 5.5min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.913386, total= 5.7min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.921705, total= 5.1min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.922244, total= 5.8min
# [CV] C=100000000.0 ...................................................
# [CV] ....................... C=100000.0, score=0.919323, total= 7.9min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.924658, total= 7.5min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.916992, total= 7.9min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.911531, total= 5.2min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.921315, total= 5.1min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.924658, total= 5.0min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.920898, total= 5.3min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.912745, total= 4.2min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.916339, total= 4.1min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.917659, total= 4.5min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.921260, total= 4.8min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.919722, total= 4.9min
# [CV] ..................... C=10000000.0, score=0.915925, total= 4.9min
# [CV] C=10000000000.0 .................................................
# [Parallel(n_jobs=-1)]: Done  97 out of 130 | elapsed: 31.6min remaining: 10.8min
# [CV] C=10000000000.0 .................................................
# [CV] ..................... C=10000000.0, score=0.911531, total= 4.8min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.921722, total= 4.7min
# [CV] C=10000000000.0 .................................................
# [CV] ..................... C=10000000.0, score=0.923307, total= 4.9min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.919922, total= 5.0min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.914370, total= 3.7min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.916914, total= 3.6min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.921705, total= 3.5min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.917659, total= 3.4min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.910784, total= 4.1min
# [CV] .................... C=100000000.0, score=0.925197, total= 3.8min
# [CV] .................... C=100000000.0, score=0.912525, total= 3.5min
# [CV] ................... C=1000000000.0, score=0.911765, total= 3.4min
# [CV] ................... C=1000000000.0, score=0.914370, total= 3.4min
# [Parallel(n_jobs=-1)]: Done 111 out of 130 | elapsed: 32.6min remaining:  5.6min
# [CV] ................... C=1000000000.0, score=0.921260, total= 3.4min
# [CV] .................... C=100000000.0, score=0.919323, total= 4.0min
# [CV] ................... C=1000000000.0, score=0.924658, total= 3.9min
# [CV] ................... C=1000000000.0, score=0.912957, total= 3.5min
# [CV] ................... C=1000000000.0, score=0.920898, total= 4.1min
# [CV] ................... C=1000000000.0, score=0.917659, total= 2.8min
# [CV] ................... C=1000000000.0, score=0.921705, total= 3.0min
# [CV] ................... C=1000000000.0, score=0.913519, total= 2.9min
# [CV] .................. C=10000000000.0, score=0.918651, total= 2.2min
# [CV] ................... C=1000000000.0, score=0.918327, total= 3.0min
# [CV] .................. C=10000000000.0, score=0.910784, total= 2.8min
# [CV] .................. C=10000000000.0, score=0.912525, total= 2.3min
# [CV] .................. C=10000000000.0, score=0.923679, total= 2.8min
# [CV] .................. C=10000000000.0, score=0.913386, total= 2.8min
# [Parallel(n_jobs=-1)]: Done 125 out of 130 | elapsed: 34.5min remaining:  1.4min
# [CV] .................. C=10000000000.0, score=0.922696, total= 2.4min
# [CV] .................. C=10000000000.0, score=0.918327, total= 2.4min
# [CV] .................. C=10000000000.0, score=0.919881, total= 2.7min
# [CV] .................. C=10000000000.0, score=0.922244, total= 2.9min
# [CV] .................. C=10000000000.0, score=0.921875, total= 3.1min
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed: 34.7min finished
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=1, shuffle=True),
#        error_score='raise',
#        estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04, 1.e+05,
#        1.e+06, 1.e+07, 1.e+08, 1.e+09, 1.e+10])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=10)

# %%
top_model.cv_results_
# Out:
# {'mean_fit_time': array([160.07418983, 547.09784508, 497.8234812 , 506.87327144,
#         479.28235402, 479.30486815, 440.14988697, 482.76981418,
#         349.25696468, 284.49078534, 235.9141752 , 199.92468781,
#         159.14813476]),
#  'mean_score_time': array([0.09631383, 0.126085  , 0.10585003, 0.05858912, 0.05606663,
#         0.05109463, 0.05444703, 0.04473746, 0.02861891, 0.03230598,
#         0.02896268, 0.02056487, 0.01423314]),
#  'mean_test_score': array([0.92521705, 0.92827545, 0.92166535, 0.91910024, 0.91771902,
#         0.91791634, 0.91742305, 0.9187056 , 0.91771902, 0.91840963,
#         0.918015  , 0.91771902, 0.91840963]),
#  'mean_train_score': array([0.96868152, 0.99473816, 0.99968212, 0.99967122, 0.99963832,
#         0.99963834, 0.99962727, 0.99964927, 0.99959449, 0.999715  ,
#         0.99964931, 0.99961639, 0.99962745]),
#  'param_C': masked_array(data=[0.01, 0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0, 100000.0,
#                     1000000.0, 10000000.0, 100000000.0, 1000000000.0,
#                     10000000000.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': ({'C': 0.01},
#   {'C': 0.1},
#   {'C': 1.0},
#   {'C': 10.0},
#   {'C': 100.0},
#   {'C': 1000.0},
#   {'C': 10000.0},
#   {'C': 100000.0},
#   {'C': 1000000.0},
#   {'C': 10000000.0},
#   {'C': 100000000.0},
#   {'C': 1000000000.0},
#   {'C': 10000000000.0}),
#  'rank_test_score': array([ 2,  1,  3,  4, 10,  9, 13,  5, 10,  6,  8, 10,  6], dtype=int32),
#  'split0_test_score': array([0.92675781, 0.9296875 , 0.92382812, 0.92285156, 0.91992188,
#         0.92480469, 0.91894531, 0.92382812, 0.91699219, 0.92089844,
#         0.91992188, 0.92089844, 0.921875  ]),
#  'split0_train_score': array([0.9678446 , 0.99495171, 0.99978051, 0.99989025, 0.99989025,
#         0.99989025, 0.99989025, 0.99989025, 0.99989025, 0.99989025,
#         0.99989025, 0.99989025, 0.99989025]),
#  'split1_test_score': array([0.93052838, 0.93933464, 0.92759295, 0.92270059, 0.92270059,
#         0.92270059, 0.91780822, 0.92465753, 0.92465753, 0.92465753,
#         0.92172211, 0.92465753, 0.92367906]),
#  'split1_train_score': array([0.96883915, 0.99462366, 0.99967084, 0.99978056, 0.99978056,
#         0.99978056, 0.99923195, 0.99978056, 0.99978056, 0.99967084,
#         0.99967084, 0.99956111, 0.99978056]),
#  'split2_test_score': array([0.91960784, 0.91862745, 0.91568627, 0.9127451 , 0.90882353,
#         0.91078431, 0.9127451 , 0.9127451 , 0.9127451 , 0.9127451 ,
#         0.91078431, 0.91176471, 0.91078431]),
#  'split2_train_score': array([0.96906538, 0.99429574, 0.99978061, 0.99978061, 0.99978061,
#         0.99967091, 0.99956121, 0.99956121, 0.99956121, 0.99967091,
#         0.99967091, 0.99956121, 0.99978061]),
#  'split3_test_score': array([0.91437008, 0.91732283, 0.91240157, 0.91732283, 0.91338583,
#         0.91043307, 0.91043307, 0.91732283, 0.91338583, 0.91633858,
#         0.91437008, 0.91437008, 0.91338583]),
#  'split3_train_score': array([0.96995614, 0.99484649, 0.99967105, 0.99967105, 0.9997807 ,
#         0.9995614 , 0.99967105, 0.99945175, 0.9997807 , 0.99967105,
#         0.9997807 , 0.9997807 , 0.9997807 ]),
#  'split4_test_score': array([0.92716535, 0.93700787, 0.93011811, 0.92125984, 0.92322835,
#         0.92224409, 0.92519685, 0.92125984, 0.92224409, 0.92125984,
#         0.92519685, 0.92125984, 0.92224409]),
#  'split4_train_score': array([0.96798246, 0.9941886 , 0.9995614 , 0.99967105, 0.99967105,
#         0.9997807 , 0.9995614 , 0.9997807 , 0.99967105, 0.99967105,
#         0.9997807 , 0.9995614 , 0.9997807 ]),
#  'split5_test_score': array([0.91988131, 0.92779426, 0.92087043, 0.91592483, 0.91889219,
#         0.91790307, 0.91691395, 0.91493571, 0.91493571, 0.91592483,
#         0.91691395, 0.91295747, 0.91988131]),
#  'split5_train_score': array([0.96975342, 0.99484932, 0.99956164, 0.99956164, 0.99846575,
#         0.99956164, 0.99956164, 0.99956164, 0.99967123, 0.99956164,
#         0.99967123, 0.99956164, 0.99945205]),
#  'split6_test_score': array([0.93260654, 0.93557978, 0.92269574, 0.9246779 , 0.92071358,
#         0.92071358, 0.9246779 , 0.92170466, 0.92170466, 0.9197225 ,
#         0.92170466, 0.92170466, 0.92269574]),
#  'split6_train_score': array([0.96822614, 0.99506957, 0.99978087, 0.9996713 , 0.99989043,
#         0.99989043, 0.99989043, 0.99978087, 0.99879478, 0.99989043,
#         0.99989043, 0.99978087, 0.99989043]),
#  'split7_test_score': array([0.92361111, 0.92261905, 0.92261905, 0.91964286, 0.9156746 ,
#         0.9156746 , 0.91666667, 0.92162698, 0.91765873, 0.91765873,
#         0.91765873, 0.91765873, 0.91865079]),
#  'split7_train_score': array([0.96790096, 0.99507011, 0.99978089, 0.99967134, 0.99978089,
#         0.99934268, 0.99967134, 0.99967134, 0.99945223, 0.99978089,
#         0.99956179, 0.99967134, 0.99967134]),
#  'split8_test_score': array([0.92246521, 0.92047714, 0.91550696, 0.91351889, 0.91451292,
#         0.91351889, 0.91252485, 0.90954274, 0.91153082, 0.91153082,
#         0.91252485, 0.91351889, 0.91252485]),
#  'split8_train_score': array([0.96955093, 0.99485214, 0.99967141, 0.99956188, 0.99978094,
#         0.99956188, 0.99967141, 0.99967141, 0.99967141, 0.99967141,
#         0.99901424, 0.99945235, 0.99967141]),
#  'split9_test_score': array([0.93525896, 0.93426295, 0.9252988 , 0.92031873, 0.91932271,
#         0.92031873, 0.91832669, 0.91932271, 0.92131474, 0.92330677,
#         0.91932271, 0.91832669, 0.91832669]),
#  'split9_train_score': array([0.96769601, 0.99463425, 0.99956198, 0.99945247, 0.99956198,
#         0.99934297, 0.99956198, 0.99934297, 0.99967148, 0.99967148,
#         0.99956198, 0.99934297, 0.99857643]),
#  'std_fit_time': array([20.74739358, 49.23715368, 61.71532776, 55.05737737, 50.40417326,
#         47.05139137, 32.38613664, 15.0155994 , 60.05129628, 19.86349054,
#         30.2894904 , 24.77021982, 16.09166404]),
#  'std_score_time': array([0.0745324 , 0.09356154, 0.07890105, 0.0109271 , 0.01662409,
#         0.01088137, 0.01534066, 0.01709781, 0.00992267, 0.0086328 ,
#         0.01203729, 0.00336124, 0.00200965]),
#  'std_test_score': array([0.00613974, 0.00772472, 0.00535796, 0.00386625, 0.00431282,
#         0.00484566, 0.00460332, 0.00470913, 0.00433215, 0.00411707,
#         0.00426213, 0.00417788, 0.00439956]),
#  'std_train_score': array([8.17232528e-04, 2.87119240e-04, 9.09795423e-05, 1.19877801e-04,
#         4.01280723e-04, 1.89965934e-04, 1.78262021e-04, 1.60979878e-04,
#         2.90041689e-04, 1.00450189e-04, 2.38900764e-04, 1.56799330e-04,
#         3.70318002e-04])}

# %%
top_model.grid_scores_
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.92522, std: 0.00614, params: {'C': 0.01},
#  mean: 0.92828, std: 0.00772, params: {'C': 0.1},
#  mean: 0.92167, std: 0.00535, params: {'C': 1.0},
#  mean: 0.91910, std: 0.00386, params: {'C': 10.0},
#  mean: 0.91772, std: 0.00430, params: {'C': 100.0},
#  mean: 0.91792, std: 0.00484, params: {'C': 1000.0},
#  mean: 0.91742, std: 0.00460, params: {'C': 10000.0},
#  mean: 0.91871, std: 0.00471, params: {'C': 100000.0},
#  mean: 0.91772, std: 0.00433, params: {'C': 1000000.0},
#  mean: 0.91841, std: 0.00412, params: {'C': 10000000.0},
#  mean: 0.91801, std: 0.00426, params: {'C': 100000000.0},
#  mean: 0.91772, std: 0.00417, params: {'C': 1000000000.0},
#  mean: 0.91841, std: 0.00439, params: {'C': 10000000000.0}]

# %%
print("Best parameters: %s - score: %0.4f" % (top_model.best_params_, top_model.best_score_))
# Out:
# Best parameters: {'C': 0.1} - score: 0.9283
