# %%
import os
import os.path
import glob
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold                                                                                                                       
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn import svm
from sklearn.model_selection import GridSearchCV
import sklearn_evaluation.plot as skplot
from sklearn.model_selection import learning_curve

import matplotlib.pyplot as plt

import numpy as np
np.random.seed(1)

from keras.preprocessing.image import img_to_array
from keras.utils import np_utils
from keras.preprocessing import image
from keras.applications.inception_resnet_v2 import InceptionResNetV2,preprocess_input

os.environ['CUDA_VISIBLE_DEVICES'] = '1'
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
imagedir = "Datasets/ByFamilyPortex"

# %%
cur_dir = os.getcwd()
os.chdir(imagedir)  # the parent folder with sub-folders

# Get number of samples per family
list_fams = sorted(os.listdir(os.getcwd()), key=str.lower)  # vector of strings with family names
no_imgs = []  # No. of samples per family
for i in range(len(list_fams)):
    os.chdir(list_fams[i])
    len1 = len(glob.glob('*.png'))  # assuming the images are stored as 'png'
    no_imgs.append(len1)
    os.chdir('..')
num_samples = np.sum(no_imgs)  # total number of all samples

# Compute the labels
y = np.zeros(num_samples)
pos = 0
label = 0
for i in no_imgs:
    print ("Label:%2d\tFamily: %15s\tNumber of images: %d" % (label, list_fams[label], i))
    for j in range(i):
        y[pos] = label
        pos += 1
    label += 1
num_classes = label

# Compute the features
width, height,channels = (224,224,3)
X = np.zeros((num_samples, width, height, channels))
cnt = 0
list_paths = [] # List of image paths
print("Processing images ...")
for i in range(len(list_fams)):
    for img_file in glob.glob(list_fams[i]+'/*.png'):
        #print("[%d] Processing image: %s" % (cnt, img_file))
        list_paths.append(os.path.join(os.getcwd(),img_file))
        img = image.load_img(img_file, target_size=(224, 224))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
        X[cnt] = x
        cnt += 1
print("Images processed: %d" %(cnt))

os.chdir(cur_dir)
# Out:
# Label: 0	Family:         allaple	Number of images: 362
# Label: 1	Family:           alman	Number of images: 325
# Label: 2	Family:          autoit	Number of images: 261
# Label: 3	Family:            daws	Number of images: 466
# Label: 4	Family:            delf	Number of images: 359
# Label: 5	Family:         gamarue	Number of images: 259
# Label: 6	Family:          ibryte	Number of images: 347
# Label: 7	Family:          loring	Number of images: 285
# Label: 8	Family:          mydoom	Number of images: 578
# Label: 9	Family:          qukart	Number of images: 253
# Label:10	Family:          ramnit	Number of images: 506
# Label:11	Family:          sality	Number of images: 1401
# Label:12	Family:          simbot	Number of images: 1148
# Label:13	Family:       softpulse	Number of images: 912
# Label:14	Family:          viking	Number of images: 183
# Label:15	Family:         virlock	Number of images: 373
# Label:16	Family:          vobfus	Number of images: 405
# Label:17	Family:          wapomi	Number of images: 345
# Label:18	Family:            zbot	Number of images: 863
# Label:19	Family:          zegost	Number of images: 505
# Processing images ...
# Images processed: 10136

# %%
X.shape
# Out:
# (10136, 224, 224, 3)

# %%
# Creating base_model
image_shape = (224, 224, 3)                                                                                                                                                                                                                                                                                            
base_model = InceptionResNetV2(weights='imagenet', input_shape=image_shape, include_top=False, pooling='avg')

# %%
print("Extracting bottleneck features from convolutional layers ...")
bnfeatures = base_model.predict(X)
# Out:
# Extracting bottleneck features from convolutional layers ...

# %%
bnfeatures.shape
# Out:
# (10136, 1536)

# %%
bnfeatures = np.reshape(bnfeatures,(bnfeatures.shape[0],-1))

# %%
bnfeatures.shape
# Out:
# (10136, 1536)

# %%
# Create stratified k-fold subsets                                                                                                                                        
kfold = 10  # no. of folds                                                                 
skf = StratifiedKFold(kfold, shuffle=True,random_state=1)

# %%
# Training top_model
C_range = np.logspace(-2, 10, 13)
param_grid = dict(C=C_range)

top_model = GridSearchCV(svm.LinearSVC(), param_grid=param_grid, cv=skf, verbose=10, n_jobs=-1)
top_model.fit(bnfeatures,y)  # Training
# Out:
# Fitting 10 folds for each of 13 candidates, totalling 130 fits
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.01 ..........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=0.1 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.903770, total= 2.7min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.892717, total= 3.3min
# [CV] C=1.0 ...........................................................
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  3.3min
# [CV] ........................... C=0.01, score=0.900391, total= 3.3min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.916501, total= 3.3min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.914706, total= 3.3min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.915851, total= 3.4min
# [CV] C=1.0 ...........................................................
# [CV] ........................... C=0.01, score=0.915758, total= 3.4min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.915354, total= 3.4min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.905378, total= 3.4min
# [CV] C=10.0 ..........................................................
# [CV] ........................... C=0.01, score=0.902077, total= 3.5min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.916667, total= 7.8min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=1.0, score=0.923529, total= 8.1min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.928150, total= 8.3min
# [CV] C=10.0 ..........................................................
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  8.4min
# [CV] ............................ C=0.1, score=0.933598, total= 8.3min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.924510, total= 8.5min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=1.0, score=0.911133, total= 8.5min
# [CV] C=10.0 ..........................................................
# [CV] ............................ C=0.1, score=0.921875, total= 8.6min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.924658, total= 8.6min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.904528, total= 8.7min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.908012, total= 8.7min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.926614, total= 8.8min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.930417, total= 8.7min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=0.1, score=0.918327, total= 8.8min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.905512, total= 8.8min
# [CV] C=100.0 .........................................................
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  9.0min
# [CV] ............................ C=1.0, score=0.909001, total= 8.3min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.919291, total= 9.0min
# [CV] C=100.0 .........................................................
# [CV] ............................ C=1.0, score=0.909722, total= 8.5min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.910156, total= 8.4min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.927435, total= 8.6min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.922311, total= 8.5min
# [CV] C=1000.0 ........................................................
# [CV] ............................ C=1.0, score=0.921705, total= 8.6min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.916667, total= 8.6min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.922701, total= 8.7min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.905512, total= 8.6min
# [CV] C=1000.0 ........................................................
# [CV] .......................... C=100.0, score=0.911133, total= 7.1min
# [CV] C=1000.0 ........................................................
# [CV] ........................... C=10.0, score=0.926295, total= 7.2min
# [CV] C=1000.0 ........................................................
# [CV] .......................... C=100.0, score=0.906496, total= 7.1min
# [CV] C=10000.0 .......................................................
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 15.9min
# [CV] .......................... C=100.0, score=0.915686, total= 7.2min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.928150, total= 7.2min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.927165, total= 8.2min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.906034, total= 7.2min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.919722, total= 7.2min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.903066, total= 8.5min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.925669, total= 8.7min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.906746, total= 8.7min
# [CV] C=10000.0 .......................................................
# [CV] ........................... C=10.0, score=0.925447, total= 8.5min
# [CV] C=10000.0 .......................................................
# [CV] .......................... C=100.0, score=0.922701, total= 8.6min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.916335, total= 5.6min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.908730, total= 8.6min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.909180, total= 5.8min
# [CV] C=100000.0 ......................................................
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 17.7min
# [CV] ......................... C=1000.0, score=0.903543, total= 5.7min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.907843, total= 5.8min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.922701, total= 5.9min
# [CV] ......................... C=1000.0, score=0.905045, total= 5.7min
# [CV] C=100000.0 ......................................................
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.906746, total= 5.6min
# [CV] C=100000.0 ......................................................
# [CV] ......................... C=1000.0, score=0.922696, total= 5.8min
# [CV] C=100000.0 ......................................................
# [CV] .......................... C=100.0, score=0.918489, total= 7.0min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.925197, total= 6.9min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.924453, total= 4.6min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.911133, total= 4.5min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.922701, total= 4.5min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.920588, total= 4.5min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.904528, total= 4.5min
# [CV] C=1000000.0 .....................................................
# [CV] ......................... C=1000.0, score=0.924303, total= 4.7min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.925197, total= 4.6min
# [CV] C=1000000.0 .....................................................
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 20.6min
# [CV] ........................ C=10000.0, score=0.908012, total= 4.6min
# [CV] C=1000000.0 .....................................................
# [CV] ........................ C=10000.0, score=0.919722, total= 4.9min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.927435, total= 4.7min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.908730, total= 4.8min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.923228, total= 4.2min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.919722, total= 4.2min
# [CV] C=10000000.0 ....................................................
# [CV] ........................ C=10000.0, score=0.918327, total= 4.8min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.903543, total= 4.3min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.909722, total= 4.2min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.908012, total= 4.3min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.921315, total= 4.2min
# [CV] C=10000000.0 ....................................................
# [CV] ....................... C=100000.0, score=0.911133, total= 4.7min
# [CV] C=100000000.0 ...................................................
# [CV] ....................... C=100000.0, score=0.920744, total= 4.7min
# [CV] C=100000000.0 ...................................................
# [CV] ....................... C=100000.0, score=0.911765, total= 4.8min
# [CV] C=100000000.0 ...................................................
# [CV] ....................... C=100000.0, score=0.925447, total= 4.7min
# [CV] C=100000000.0 ...................................................
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 22.6min
# [CV] ...................... C=1000000.0, score=0.912109, total= 4.6min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.920744, total= 4.8min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.918627, total= 4.0min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.901575, total= 3.9min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.920714, total= 4.0min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.909990, total= 4.1min
# [CV] C=100000000.0 ...................................................
# [CV] ...................... C=1000000.0, score=0.926295, total= 4.0min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.921260, total= 4.2min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.924453, total= 4.1min
# [CV] C=1000000000.0 ..................................................
# [CV] ...................... C=1000000.0, score=0.909722, total= 4.7min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.903770, total= 4.0min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.922696, total= 4.0min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.903543, total= 4.1min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.929134, total= 4.1min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.923459, total= 4.0min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.920319, total= 4.0min
# [CV] C=1000000000.0 ..................................................
# [CV] ..................... C=10000000.0, score=0.911133, total= 4.8min
# [CV] C=10000000000.0 .................................................
# [Parallel(n_jobs=-1)]: Done  97 out of 130 | elapsed: 26.5min remaining:  9.0min
# [CV] ..................... C=10000000.0, score=0.916830, total= 4.8min
# [CV] C=10000000000.0 .................................................
# [CV] ..................... C=10000000.0, score=0.899110, total= 4.8min
# [CV] C=10000000000.0 .................................................
# [CV] ..................... C=10000000.0, score=0.919608, total= 4.8min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.912109, total= 4.8min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.921722, total= 4.8min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.921569, total= 4.9min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.904528, total= 4.7min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.924213, total= 4.9min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.901786, total= 3.8min
# [CV] C=10000000000.0 .................................................
# [CV] .................... C=100000000.0, score=0.902077, total= 4.7min
# [CV] .................... C=100000000.0, score=0.924453, total= 3.9min
# [CV] .................... C=100000000.0, score=0.925299, total= 3.8min
# [CV] ................... C=1000000000.0, score=0.911133, total= 3.7min
# [CV] ................... C=1000000000.0, score=0.921569, total= 3.8min
# [Parallel(n_jobs=-1)]: Done 111 out of 130 | elapsed: 28.5min remaining:  4.9min
# [CV] ................... C=1000000000.0, score=0.923679, total= 3.8min
# [CV] .................... C=100000000.0, score=0.915758, total= 4.6min
# [CV] ................... C=1000000000.0, score=0.907023, total= 3.4min
# [CV] ................... C=1000000000.0, score=0.919291, total= 3.5min
# [CV] ................... C=1000000000.0, score=0.902778, total= 3.4min
# [CV] ................... C=1000000000.0, score=0.923459, total= 3.4min
# [CV] ................... C=1000000000.0, score=0.922696, total= 3.5min
# [CV] ................... C=1000000000.0, score=0.923307, total= 3.4min
# [CV] ................... C=1000000000.0, score=0.904528, total= 4.3min
# [CV] .................. C=10000000000.0, score=0.921569, total= 3.6min
# [CV] .................. C=10000000000.0, score=0.906250, total= 3.8min
# [CV] .................. C=10000000000.0, score=0.904528, total= 3.7min
# [CV] .................. C=10000000000.0, score=0.923679, total= 3.7min
# [CV] .................. C=10000000000.0, score=0.907023, total= 3.5min
# [Parallel(n_jobs=-1)]: Done 125 out of 130 | elapsed: 30.5min remaining:  1.2min
# [CV] .................. C=10000000000.0, score=0.928150, total= 3.6min
# [CV] .................. C=10000000000.0, score=0.910714, total= 3.3min
# [CV] .................. C=10000000000.0, score=0.920714, total= 3.5min
# [CV] .................. C=10000000000.0, score=0.913347, total= 2.5min
# [CV] .................. C=10000000000.0, score=0.925447, total= 2.6min
# [Parallel(n_jobs=-1)]: Done 130 out of 130 | elapsed: 30.8min finished
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=1, shuffle=True),
#        error_score='raise',
#        estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03, 1.e+04, 1.e+05,
#        1.e+06, 1.e+07, 1.e+08, 1.e+09, 1.e+10])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=10)

# %%
top_model.cv_results_
# Out:
# {'mean_fit_time': array([199.11358862, 511.13323956, 513.3454052 , 504.06899216,
#         437.03387876, 339.18612418, 278.09537051, 265.99049609,
#         255.4676914 , 259.04638751, 269.06370804, 217.78548965,
#         203.17566736]),
#  'mean_score_time': array([0.09598963, 0.10461843, 0.12229931, 0.04427633, 0.03151994,
#         0.03221908, 0.02690909, 0.02649527, 0.02627358, 0.02431164,
#         0.02711611, 0.01616368, 0.01391392]),
#  'mean_test_score': array([0.90824783, 0.92127072, 0.91742305, 0.91692976, 0.91535122,
#         0.91515391, 0.91663378, 0.91544988, 0.91653512, 0.91495659,
#         0.91535122, 0.91594317, 0.91614049]),
#  'mean_train_score': array([0.9488399 , 0.99165789, 0.99953947, 0.99956168, 0.99951777,
#         0.99930913, 0.99969308, 0.99964923, 0.99967114, 0.99944081,
#         0.99970407, 0.99969306, 0.99953966]),
#  'param_C': masked_array(data=[0.01, 0.1, 1.0, 10.0, 100.0, 1000.0, 10000.0, 100000.0,
#                     1000000.0, 10000000.0, 100000000.0, 1000000000.0,
#                     10000000000.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': ({'C': 0.01},
#   {'C': 0.1},
#   {'C': 1.0},
#   {'C': 10.0},
#   {'C': 100.0},
#   {'C': 1000.0},
#   {'C': 10000.0},
#   {'C': 100000.0},
#   {'C': 1000000.0},
#   {'C': 10000000.0},
#   {'C': 100000000.0},
#   {'C': 1000000000.0},
#   {'C': 10000000000.0}),
#  'rank_test_score': array([13,  1,  2,  3,  9, 11,  4,  8,  5, 12,  9,  7,  6], dtype=int32),
#  'split0_test_score': array([0.90039062, 0.921875  , 0.91113281, 0.91015625, 0.91113281,
#         0.90917969, 0.91113281, 0.91113281, 0.91210938, 0.91113281,
#         0.91210938, 0.91113281, 0.90625   ]),
#  'split0_train_score': array([0.94820018, 0.9917691 , 0.99967076, 0.99978051, 0.99956102,
#         0.99989025, 0.99978051, 0.99989025, 0.99967076, 0.99967076,
#         0.99989025, 0.99989025, 0.99978051]),
#  'split1_test_score': array([0.91585127, 0.92661448, 0.92465753, 0.92270059, 0.92270059,
#         0.92270059, 0.92270059, 0.92074364, 0.92074364, 0.91682975,
#         0.92172211, 0.92367906, 0.92367906]),
#  'split1_train_score': array([0.94678517, 0.99155146, 0.99868334, 0.99967084, 0.99967084,
#         0.99967084, 0.99967084, 0.99967084, 0.99967084, 0.99802502,
#         0.99967084, 0.99945139, 0.99945139]),
#  'split2_test_score': array([0.91470588, 0.9245098 , 0.92352941, 0.91666667, 0.91568627,
#         0.90784314, 0.92058824, 0.91176471, 0.91862745, 0.91960784,
#         0.92156863, 0.92156863, 0.92156863]),
#  'split2_train_score': array([0.94877139, 0.99177271, 0.99956121, 0.99967091, 0.99956121,
#         0.99550241, 0.99967091, 0.99923212, 0.99967091, 0.99956121,
#         0.99967091, 0.99967091, 0.99967091]),
#  'split3_test_score': array([0.89271654, 0.90452756, 0.90551181, 0.90551181, 0.90649606,
#         0.90354331, 0.90452756, 0.90354331, 0.9015748 , 0.90354331,
#         0.90452756, 0.90452756, 0.90452756]),
#  'split3_train_score': array([0.9495614 , 0.99155702, 0.99967105, 0.99967105, 0.99967105,
#         0.99967105, 0.99967105, 0.99967105, 0.99967105, 0.99967105,
#         0.99967105, 0.99967105, 0.99967105]),
#  'split4_test_score': array([0.91535433, 0.92814961, 0.91929134, 0.92716535, 0.92814961,
#         0.92519685, 0.92519685, 0.92322835, 0.92125984, 0.92913386,
#         0.9242126 , 0.91929134, 0.92814961]),
#  'split4_train_score': array([0.94901316, 0.99144737, 0.99923246, 0.99967105, 0.99967105,
#         0.9997807 , 0.99967105, 0.9997807 , 0.99967105, 0.99967105,
#         0.99967105, 0.9995614 , 0.9995614 ]),
#  'split5_test_score': array([0.90207715, 0.90801187, 0.90900099, 0.90306627, 0.90603363,
#         0.90504451, 0.90801187, 0.90801187, 0.90999011, 0.89910979,
#         0.90207715, 0.90702275, 0.90702275]),
#  'split5_train_score': array([0.95013699, 0.99210959, 0.99967123, 0.99978082, 0.99967123,
#         0.99978082, 0.99967123, 0.99956164, 0.99956164, 0.99923288,
#         0.99978082, 0.99978082, 0.99978082]),
#  'split6_test_score': array([0.91575818, 0.93359762, 0.92170466, 0.92566898, 0.9197225 ,
#         0.92269574, 0.9197225 , 0.9197225 , 0.92071358, 0.92269574,
#         0.91575818, 0.92269574, 0.92071358]),
#  'split6_train_score': array([0.948614  , 0.99200175, 0.99989043, 0.99989043, 0.99989043,
#         0.99989043, 0.99989043, 0.99989043, 0.99989043, 0.99978087,
#         0.99989043, 0.99989043, 0.99868522]),
#  'split7_test_score': array([0.90376984, 0.91666667, 0.90972222, 0.90674603, 0.90873016,
#         0.90674603, 0.90873016, 0.90972222, 0.90972222, 0.90376984,
#         0.90178571, 0.90277778, 0.91071429]),
#  'split7_train_score': array([0.94993427, 0.99057844, 0.99967134, 0.99978089, 0.99978089,
#         0.99978089, 0.99978089, 0.99967134, 0.99967134, 0.99978089,
#         0.99978089, 0.99978089, 0.99978089]),
#  'split8_test_score': array([0.91650099, 0.9304175 , 0.92743539, 0.92544732, 0.91848907,
#         0.92445328, 0.92743539, 0.92544732, 0.92445328, 0.92345924,
#         0.92445328, 0.92345924, 0.92544732]),
#  'split8_train_score': array([0.94819277, 0.99200438, 0.99967141, 0.99967141, 0.99824754,
#         0.99967141, 0.99978094, 0.99978094, 0.99978094, 0.99978094,
#         0.99978094, 0.99978094, 0.99978094]),
#  'split9_test_score': array([0.90537849, 0.91832669, 0.92231076, 0.92629482, 0.91633466,
#         0.92430279, 0.91832669, 0.92131474, 0.92629482, 0.92031873,
#         0.9252988 , 0.92330677, 0.91334661]),
#  'split9_train_score': array([0.94918966, 0.99178712, 0.99967148, 0.99802891, 0.99945247,
#         0.99945247, 0.99934297, 0.99934297, 0.99945247, 0.99923346,
#         0.99923346, 0.99945247, 0.99923346]),
#  'std_fit_time': array([12.42888669, 18.18409214, 13.16963908, 26.14160911, 47.95072221,
#         36.73292292,  8.22550056, 15.71274825, 18.54479798, 23.11483028,
#         25.61321728, 16.75733302, 27.12068355]),
#  'std_score_time': array([0.05959453, 0.05455304, 0.10384709, 0.01477493, 0.00936229,
#         0.0113606 , 0.00536822, 0.00547586, 0.00481199, 0.00491704,
#         0.00472261, 0.00405604, 0.00265856]),
#  'std_test_score': array([0.00803041, 0.00898587, 0.0073967 , 0.00919477, 0.00689406,
#         0.00883794, 0.00753811, 0.00709049, 0.00742706, 0.00952317,
#         0.00908705, 0.00815065, 0.00832007]),
#  'std_train_score': array([0.00093052, 0.0004142 , 0.00032481, 0.00051587, 0.00043859,
#         0.00127467, 0.00013676, 0.00020683, 0.00010952, 0.00051099,
#         0.0001769 , 0.00015348, 0.00033154])}

# %%
top_model.grid_scores_
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/model_selection/_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.90825, std: 0.00802, params: {'C': 0.01},
#  mean: 0.92127, std: 0.00899, params: {'C': 0.1},
#  mean: 0.91742, std: 0.00740, params: {'C': 1.0},
#  mean: 0.91693, std: 0.00920, params: {'C': 10.0},
#  mean: 0.91535, std: 0.00689, params: {'C': 100.0},
#  mean: 0.91515, std: 0.00884, params: {'C': 1000.0},
#  mean: 0.91663, std: 0.00754, params: {'C': 10000.0},
#  mean: 0.91545, std: 0.00709, params: {'C': 100000.0},
#  mean: 0.91654, std: 0.00743, params: {'C': 1000000.0},
#  mean: 0.91496, std: 0.00953, params: {'C': 10000000.0},
#  mean: 0.91535, std: 0.00910, params: {'C': 100000000.0},
#  mean: 0.91594, std: 0.00816, params: {'C': 1000000000.0},
#  mean: 0.91614, std: 0.00831, params: {'C': 10000000000.0}]

# %%
print("Best parameters: %s - score: %0.4f" % (top_model.best_params_, top_model.best_score_))
# Out:
# Best parameters: {'C': 0.1} - score: 0.9213
